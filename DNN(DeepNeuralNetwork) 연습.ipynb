# %% [markdown]
# 1. 기본 파라미터 설정
# 2. 분류 DNN 모델 구현
# 3. 데이터 준비
# 4. 분류 DNN의 학습 및 성능 평가

# %%
from keras import models, layers

# %%
# 기본 파라미터 설정
Nin = 784
Nh_1 = [100, 50]
number_of_class = 10
Nout = number_of_class

# %%
# 분류 DNN 모델 구현
class DNN(models.Sequential):
  def __init__(self, Nin, Nh_1, Nout):
    super().__init__()
    self.add(layers.Dense(Nh_1[0], activation='relu', input_shape=(Nin,), name='Hidden-1'))
    self.add(layers.Dropout(0.2))
    self.add(layers.Dense(Nout, activation='softmax'))
    self.compile(loss='categorical_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])

# %%
# 데이터 준비
import numpy as np
from keras import datasets
from keras.utils import np_utils
(X_train, y_train), (X_test, y_test) = datasets.mnist.load_data()
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
L, W, H = X_train.shape
X_train = X_train.reshape(-1 , W*H)
X_test = X_test.reshape(-1 , W*H)
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
# 분류 DNN 학습 및 성능 평가
model = DNN(Nin, Nh_1, Nout)
history = model.fit(X_train, y_train, epochs=10, batch_size=100, validation_split=0.2)
performace_test = model.evaluate(X_test, y_test, batch_size = 100)
print(performace_test)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 3s 53us/step - loss: 0.4436 - acc: 0.8726 - val_loss: 0.2101 - val_acc: 0.9427
# Epoch 2/10
# 48000/48000 [==============================] - 2s 47us/step - loss: 0.2219 - acc: 0.9358 - val_loss: 0.1617 - val_acc: 0.9553
# Epoch 3/10
# 48000/48000 [==============================] - 2s 45us/step - loss: 0.1682 - acc: 0.9500 - val_loss: 0.1344 - val_acc: 0.9625
# Epoch 4/10
# 48000/48000 [==============================] - 2s 46us/step - loss: 0.1386 - acc: 0.9590 - val_loss: 0.1153 - val_acc: 0.9655
# Epoch 5/10
# 48000/48000 [==============================] - 2s 46us/step - loss: 0.1203 - acc: 0.9645 - val_loss: 0.1081 - val_acc: 0.9668
# Epoch 6/10
# 48000/48000 [==============================] - 2s 46us/step - loss: 0.1046 - acc: 0.9694 - val_loss: 0.0978 - val_acc: 0.9709
# Epoch 7/10
# 48000/48000 [==============================] - 2s 46us/step - loss: 0.0936 - acc: 0.9720 - val_loss: 0.0935 - val_acc: 0.9724
# Epoch 8/10
# 48000/48000 [==============================] - 2s 47us/step - loss: 0.0850 - acc: 0.9743 - val_loss: 0.0886 - val_acc: 0.9728
# Epoch 9/10
# 48000/48000 [==============================] - 2s 46us/step - loss: 0.0775 - acc: 0.9768 - val_loss: 0.0883 - val_acc: 0.9722
# Epoch 10/10
# 48000/48000 [==============================] - 2s 46us/step - loss: 0.0712 - acc: 0.9782 - val_loss: 0.0854 - val_acc: 0.9738
# 10000/10000 [==============================] - 0s 15us/step
# [0.07935372244217433, 0.9759000062942504]
