# %%
import tensorflow as tf
import tensorflow.contrib.eager as tfe

# %%
x_train = [[1.,2.],
           [2.,3.],
           [3.,1.],
           [4.,3.],
           [5.,3.],
           [6.,2.]]
y_train =[[0.],
          [0.],
          [0.],
          [1.],
          [1.],
          [1.]]
x_test = [[5.,2.]]
y_test = [[1.]]

# %%
tf.enable_eager_execution()
dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(len(x_train))

# %%
# y = xW + b   
W = tf.Variable(tf.zeros([2,1]), name='weight')
b = tf.Variable(tf.zeros([1]), name ='bias')
print(W)
print(dataset)
# Out:
# <tf.Variable 'weight:0' shape=(2, 1) dtype=float32, numpy=
# array([[0.],
#        [0.]], dtype=float32)>
# <DatasetV1Adapter shapes: ((?, 2), (?, 1)), types: (tf.float32, tf.float32)>

# %%
# Sigmoid함수  1/(1+e^-x)
def logistic_regression(features):
  hypothesis = tf.div(1., 1. + tf.exp(tf.matmul(features, W) + b)) 
  return hypothesis

# %%
# cost 함수  -(y * log(hypothesis) + (1 - y) * log(1 - hypothesis))
def loss_fn(features, labels):
  hypothesis = logistic_regression(features)
  cost = -tf.reduce_mean(labels * tf.log(loss_fn(hypothesis))+(1-labels)*tf.log(1-hypothesis))
  return cost

# %%
# Gradient Descent 
def grad(hypothesis, features, labels):
  with tf.GradientTape() as tape:
    loss_value = loss_fn(hypothesis, labels)
    return tape.gradient(loss_value, [W,b])
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)

# %%
for step in range(5):
  for features, labels in tfe.Iterator(dataset):
    grads = grad(logistic_regression(features), features, labels)
    optimizer.apply_gradients(grads_and_vars=zip(grads,[W,b]))
    if step % 100 == 0:
      print("Iter : {}, Loss:{:.4f}".format(step,loss_fn(logistic_regression(features),labels)))
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-29-9883e0c7c540> in <module>()
#       1 for step in range(5):
#       2   for features, labels in tfe.Iterator(dataset):
# ----> 3     grads = grad(logistic_regression(features), features, labels)
#       4     optimizer.apply_gradients(grads_and_vars=zip(grads,[W,b]))
#       5     if step % 100 == 0:
#
# <ipython-input-28-d51c6f13d9e7> in grad(hypothesis, features, labels)
#       1 def grad(hypothesis, features, labels):
#       2   with tf.GradientTape() as tape:
# ----> 3     loss_value = loss_fn(hypothesis, labels)
#       4     return tape.gradient(loss_value, [W,b])
#       5 optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
#
# <ipython-input-27-d1cdf7816a5b> in loss_fn(features, labels)
#       1 def loss_fn(features, labels):
# ----> 2   hypothesis = logistic_regression(features)
#       3   cost = -tf.reduce_mean(labels * tf.log(loss_fn(hypothesis))+(1-labels)*tf.log(1-hypothesis))
#       4   return cost
#
# <ipython-input-26-15447c5ce77f> in logistic_regression(features)
#       1 def logistic_regression(features):
# ----> 2   hypothesis = tf.div(1., 1. + tf.exp(tf.matmul(features, W) + b))
#       3   return hypothesis
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py in matmul(a, b, transpose_a, transpose_b, adjoint_a, adjoint_b, a_is_sparse, b_is_sparse, name)
#    2645     else:
#    2646       return gen_math_ops.mat_mul(
# -> 2647           a, b, transpose_a=transpose_a, transpose_b=transpose_b, name=name)
#    2648
#    2649
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_math_ops.py in mat_mul(a, b, transpose_a, transpose_b, name)
#    5913       else:
#    5914         message = e.message
# -> 5915       _six.raise_from(_core._status_to_exception(e.code, message), None)
#    5916   # Add nodes to the TensorFlow graph.
#    5917   if transpose_a is None:
#
# /usr/local/lib/python3.6/dist-packages/six.py in raise_from(value, from_value)
#
# InvalidArgumentError: Matrix size-incompatible: In[0]: [6,1], In[1]: [2,1] [Op:MatMul] name: MatMul/

# %%
def accuracy_fn(hypothesis, labels):
  predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
  accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, labels), dtype=tf.int32))
  return accuracy

test_acc = accuracy_fn(logistic_regression(x_test), y_test)
# Out:
# W0805 01:53:20.338723 139931699275648 deprecation.py:323] From <ipython-input-8-85d707864361>:2: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
