# %%
# 1번
print("Hello")
# Out:
# Hello

# %%
# 2번
print("Hello World")

# %%
# 3번
print("Hello")
print("World")

# %%
# 4번 
print("'Hello'")

# %%
# 5번
print('"Hello World"')

# %%
# 6번
print('"!@#$%^&*()"')

# %%
# 7번
print('"C:\Download\hello.cpp"')

# %%
# 10,11,12번
a = input()
print(a)

# %%
# 13번
a,b = input().split()
print(a,b)

# %%
# 14번
a,b = input().split()
print(b,a)

# %%
# 15번
a= float(input())
print("%.2f" %a)

# %%
# 17번
a = input()
print(a,a,a)

# %%
# 18번 
a = input()
print(a)

# %%
# 19번
a,b,c= input().split(".")
a = int(a)
b = int(b)
c = int(c)
print("{0:04d}.{1:02d}.{2:02d}".format(a,b,c))

# print('%04d' % int(a), end='.')
# print('%02d' % int(b), end='.')
# print('%02d' % int(c))
# Out:
# 123
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-30be08f78b89> in <module>()
# ----> 1 a,b,c= input().split(".")
#       2 a = int(a)
#       3 b = int(b)
#       4 c = int(c)
#       5 print("{0:04d}.{1:02d}.{2:02d}".format(a,b,c))
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
# 20번
a,b = input().split('-')
print("{0}{1}".format(a,b))
#print(a+b)

# %%
# 21,22번
a = input()
print(a)

# %%
# 23번
a,b = input().split('.')
print(a)
print(b)

# %%
# 24번
a = input()
for s in a:
    print("\'{0}\'".format(s))
# Out:
# 1
# '1'

# %%
# 25번
a = int(input())
print("[{0:<05d}]".format(int(a/10000)))
a %= 10000
print("[{0:<04d}]".format(int(a/1000)))
a %= 1000
print("[{0:<03d}]".format(int(a/100)))
a %= 100
print("[{0:<02d}]".format(int(a/10)))
a %= 10
print("[{0}]".format(int(a)))


# n=input()

# print("["+str(int(n[0])*10000)+"]")
# print("["+str(int(n[1])*1000)+"]")
# print("["+str(int(n[2])*100)+"]")
# print("["+str(int(n[3])*10)+"]")
# print("["+str(int(n[4]))+"]")
# Out:
# 77777
# [70000]
# [7000]
# [700]
# [70]
# [7]

# %%
# 26번
a,b,c = input().split(':')
print(b)
# Out:
# 17:23:57
# 23

# %%
# 27번
a,b,c = input().split('.')
print("{2}-{1}-{0}".format(a,b,c))
# Out:
# 2014.07.15
# 15-07-2014

# %%
# 28, 29, 30번
a = input()
print(a)
# Out:
# 2147483648
# 2147483648

# %%
# 31번
a = input()
a = oct(int(a))
print(a[2:])

# a=input()
# n=int(a)
# print('%o' % n)
# Out:
# 10
# 12

# %%
# 32번
a=input()
n=int(a)
print('%x' % n)
# Out:
# 255
# ff

# %%
# 33번
a=input()
n=int(a)
print('%X' % n)
# Out:
# 255
# FF

# %%
# 34번
a = int(input(), 8)
print('%d' % a)

# a=input()
# n=int(a, 8)
# print(n)
# Out:
# 13
# 11

# %%
# 35번
a = int(input(), 16)
print('%o' %a)

# a=input()
# n=int(a, 16)
# print('%o' % n)
# Out:
# f
# 17

# %%
# 36번
a = input()
print('%d' % ord(a))

# a=input()
# n=ord(a)
# print(n)
# Out:
# A
# 65

# %%
# 37번
a = int(input())
print('%c' % chr(a))

# a=int(input())
# n=chr(a)
# print(n)
# Out:
# 65
# A

# %%
# 38, 39번
a,b = input().split()
print(int(a) + int(b))
# Out:
# 123 -123
# 0

# %%
# 40번
a = input()
print(-int(a))
# Out:
# 1
# -1

# %%
# 41번    ord = 아스키코드 -> 정수 , chr = 정수 -> 아스키코드
a = input()
a = ord(a) + 1
print(chr(a))
# Out:
# a
# b

# %%
# 42번    // = 나누기 연산 후 소수점 이하의 수를 버리고, 정수 부분의 수만 구함
a,b = input().split()
c = int(a)/int(b)
print('%d' % c)

# a,b=input().split()
# x=int(a)
# y=int(b)
# print(x//y)
# Out:
# 1 3
# 0

# %%
# 43번
a,b=input().split()
x=int(a)
y=int(b)
print(x%y)
# Out:
# 3 7
# 3

# %%
# 44번
a = int(input())
print(a+1)
# Out:
# 1
# 2

# %%
# 45번
a,b = input().split()
a = int(a)
b = int(b)
print(a+b)
print(a-b)
print(a*b)
print(a//b)
print(a%b)
print("%.2f" %(a/b))
#print("{0:<03}".format(a/b))
# Out:
# 3 3
# 6
# 0
# 9
# 1
# 0
# 1.00

# %%
# 46번
a,b,c = input().split()
a = int(a)
b = int(b)
c = int(c)
d = a+b+c
print(d)
print('%.1f' %(d/3))
# Out:
# 1 2 3
# 6
# 2.0
